# %% [markdown]
# # Database Preparation

# %%
# Install firebase sdk
#!pip install firebase-admin

# %%
# Import libraries
import firebase_admin
from firebase_admin import credentials, firestore

# %%
# Initialize firebase
cred = credentials.Certificate("serviceAccountKey.json")
firebase_admin.initialize_app(cred)
db = firestore.client()

# %%
question_data = [
    {
        "category": "Completion",
        "items": [
            {
                "type": "Table Completion",
                "instruction": "Complete the table below.",
                "answer_format": "Write ONE WORD AND / OR A NUMBER for each answer."
            },
            {
                "type": "Note Completion",
                "instruction": "Complete the note below.",
                "answer_format": "Write ONE WORD AND / OR A NUMBER for each answer."
            },
            {
                "type": "Form Completion",
                "instruction": "Complete the form below.",
                "answer_format": "Write ONE WORD AND / OR A NUMBER for each answer."
            }
        ]
    },
    {
        "category": "Labelling",
        "items": [
            {
                "type": "Plan Labelling",
                "instruction": "Label the plan below.",
                "answer_format": "Write the correct letter, A-I."
            },
            {
                "type": "Map Labelling",
                "instruction": "Label the map below.",
                "answer_format": "Write the correct letter, A-I."
            }
        ]
    },
    {
        "category": "Multiple Choice",
        "items": [
            {
                "type": "Part 2",
                "instruction": "Choose TWO letters, A-E."
            },
            {
                "type": "Part 3",
                "instruction": "Choose the correct letter, A, B or C."
            }
        ]
    },
    {
        "category": "Flow Chart",
        "items": [
            {
                "type": "Flow Chart Completion",
                "instruction": "Complete the flow-chart below.",
                "answer_format": "Choose SIX answers from the box and write the correct letters, A-I."
            }
        ]
    },
    {
        "category": "Sentence Completion",
        "items": [
            {
                "type": "Two Words",
                "instruction": "Complete the notes below.",
                "answer_format": "Write NO MORE THAN TWO WORDS for each answer."
            },
            {
                "type": "One Words",
                "instruction": "Complete the sentences below.",
                "answer_format": "Write ONE WORD ONLY for each answer."
            }
        ]
    },
    {
        "category": "Matching Tasks",
        "items": [
            {
                "type": "Matching",
                "instruction": "Choose FIVE answers from the box and write the correct letter, A-G."
            }
        ]
    }
]

# %%
# Reference for the question collection
collection_ref = db.collection("QuestionTypes")

for q in question_data:
    custom_id = q["category"].replace(" ", "_").replace(",", "").replace("(", "").replace(")", "").lower()
    doc_ref = collection_ref.document(custom_id)
    doc_ref.set(q)
    print(f"Addded: {q['category']}")

print("All data stored successfully.")
# Out:
# Addded: Completion
# Addded: Labelling
# Addded: Multiple Choice
# Addded: Flow Chart
# Addded: Sentence Completion
# Addded: Matching Tasks
# All data stored successfully.
